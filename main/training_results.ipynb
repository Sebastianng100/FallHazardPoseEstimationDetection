# %% [markdown]
# efficientnet_fall_classification_baseline:
#
# Epoch 01/10 | Train L 0.6887 A 0.591 P 0.553 R 0.405 F1 0.467 | Val L 0.0000 A 0.631 P 0.464 R 0.333 F1 0.388
#   Train CM:
# [[156  55]
#  [100  68]]
#   Val   CM:
# [[57 15]
#  [26 13]]
#
# Saved best model
# Epoch 02/10 | Train L 0.6576 A 0.662 P 0.639 R 0.548 F1 0.590 | Val L 0.0000 A 0.622 P 0.463 R 0.487 F1 0.475
#   Train CM:
# [[159  52]
#  [ 76  92]]
#   Val   CM:
# [[50 22]
#  [20 19]]
#
# Saved best model
# Epoch 03/10 | Train L 0.6240 A 0.739 P 0.697 R 0.726 F1 0.711 | Val L 0.0000 A 0.658 P 0.512 R 0.564 F1 0.537
#   Train CM:
# [[158  53]
#  [ 46 122]]
#   Val   CM:
# [[51 21]
#  [17 22]]
#
# Saved best model
# Epoch 04/10 | Train L 0.6036 A 0.726 P 0.674 R 0.738 F1 0.705 | Val L 0.0000 A 0.658 P 0.510 R 0.667 F1 0.578
#   Train CM:
# [[151  60]
#  [ 44 124]]
#   Val   CM:
# [[47 25]
#  [13 26]]
#
# Saved best model
# Epoch 05/10 | Train L 0.5872 A 0.773 P 0.728 R 0.780 F1 0.753 | Val L 0.0000 A 0.685 P 0.540 R 0.692 F1 0.607
#   Train CM:
# [[162  49]
#  [ 37 131]]
#   Val   CM:
# [[49 23]
#  [12 27]]
#
# Saved best model
# Epoch 06/10 | Train L 0.5710 A 0.770 P 0.724 R 0.780 F1 0.751 | Val L 0.0000 A 0.694 P 0.549 R 0.718 F1 0.622
#   Train CM:
# [[161  50]
#  [ 37 131]]
#   Val   CM:
# [[49 23]
#  [11 28]]
#
# Saved best model
# Epoch 07/10 | Train L 0.5540 A 0.807 P 0.768 R 0.810 F1 0.788 | Val L 0.0000 A 0.712 P 0.569 R 0.744 F1 0.644
#   Train CM:
# [[170  41]
#  [ 32 136]]
#   Val   CM:
# [[50 22]
#  [10 29]]
#
# Saved best model
# Epoch 08/10 | Train L 0.5337 A 0.805 P 0.753 R 0.833 F1 0.791 | Val L 0.0000 A 0.730 P 0.596 R 0.718 F1 0.651
#   Train CM:
# [[165  46]
#  [ 28 140]]
#   Val   CM:
# [[53 19]
#  [11 28]]
#
# Saved best model
# Epoch 09/10 | Train L 0.5331 A 0.823 P 0.782 R 0.833 F1 0.807 | Val L 0.0000 A 0.667 P 0.528 R 0.487 F1 0.507
#   Train CM:
# [[172  39]
#  [ 28 140]]
#   Val   CM:
# [[55 17]
#  [20 19]]
#
# Epoch 10/10 | Train L 0.5190 A 0.813 P 0.768 R 0.827 F1 0.797 | Val L 0.0000 A 0.703 P 0.562 R 0.692 F1 0.621
#   Train CM:
# [[169  42]
#  [ 29 139]]
#   Val   CM:
# [[51 21]
#  [12 27]]
#
# Done.

# %% [markdown]
# efficientnet_fall_classification:
#
# Epoch 01/10 | Train L 0.6872 A 0.522 P 0.441 R 0.292 F1 0.351 | Val L 0.6615 A 0.703 P 0.636 R 0.359 F1 0.459
#   Train CM:
# [[149  62]
#  [119  49]]
#   Val   CM:
# [[64  8]
#  [25 14]]
#
# Saved best model
# Epoch 02/10 | Train L 0.6699 A 0.594 P 0.561 R 0.381 F1 0.454 | Val L 0.6651 A 0.649 P 0.500 R 0.385 F1 0.435
#   Train CM:
# [[161  50]
#  [104  64]]
#   Val   CM:
# [[57 15]
#  [24 15]]
#
# Epoch 03/10 | Train L 0.6581 A 0.612 P 0.591 R 0.405 F1 0.481 | Val L 0.6584 A 0.676 P 0.556 R 0.385 F1 0.455
#   Train CM:
# [[164  47]
#  [100  68]]
#   Val   CM:
# [[60 12]
#  [24 15]]
#
# Epoch 04/10 | Train L 0.6482 A 0.609 P 0.586 R 0.405 F1 0.479 | Val L 0.6535 A 0.712 P 0.652 R 0.385 F1 0.484
#   Train CM:
# [[163  48]
#  [100  68]]
#   Val   CM:
# [[64  8]
#  [24 15]]
#
# Saved best model
# Epoch 05/10 | Train L 0.6451 A 0.652 P 0.643 R 0.482 F1 0.551 | Val L 0.6441 A 0.721 P 0.667 R 0.410 F1 0.508
#   Train CM:
# [[166  45]
#  [ 87  81]]
#   Val   CM:
# [[64  8]
#  [23 16]]
#
# Saved best model
# Epoch 06/10 | Train L 0.6376 A 0.631 P 0.600 R 0.500 F1 0.545 | Val L 0.6491 A 0.676 P 0.545 R 0.462 F1 0.500
#   Train CM:
# [[155  56]
#  [ 84  84]]
#   Val   CM:
# [[57 15]
#  [21 18]]
#
# Epoch 07/10 | Train L 0.6286 A 0.594 P 0.549 R 0.464 F1 0.503 | Val L 0.6418 A 0.712 P 0.640 R 0.410 F1 0.500
#   Train CM:
# [[147  64]
#  [ 90  78]]
#   Val   CM:
# [[63  9]
#  [23 16]]
#
# Epoch 08/10 | Train L 0.6339 A 0.578 P 0.530 R 0.423 F1 0.470 | Val L 0.6391 A 0.730 P 0.680 R 0.436 F1 0.531
#   Train CM:
# [[148  63]
#  [ 97  71]]
#   Val   CM:
# [[64  8]
#  [22 17]]
#
# Saved best model
# Epoch 09/10 | Train L 0.6278 A 0.646 P 0.621 R 0.518 F1 0.565 | Val L 0.6395 A 0.721 P 0.625 R 0.513 F1 0.563
#   Train CM:
# [[158  53]
#  [ 81  87]]
#   Val   CM:
# [[60 12]
#  [19 20]]
#
# Saved best model
# Epoch 10/10 | Train L 0.6278 A 0.646 P 0.635 R 0.476 F1 0.544 | Val L 0.6406 A 0.712 P 0.621 R 0.462 F1 0.529
#   Train CM:
# [[165  46]
#  [ 88  80]]
#   Val   CM:
# [[61 11]
#  [21 18]]
#
# Done.

# %% [markdown]
# resnet_fall_classification_baseline:
#
# Epoch 01/10 | Train L 0.7016 A 0.501 P 0.457 R 0.667 F1 0.542 | Val L 0.0000 A 0.649 P 0.500 R 0.564 F1 0.530
#   Train CM:
# [[ 78 133]
#  [ 56 112]]
#   Val   CM:
# [[50 22]
#  [17 22]]
#
# Saved best model (val F1=0.530) → C:\Users\Asus\Desktop\School_SIT\Year_2_Tri_1\COMPUTER_VISION\FallHazardPoseEstimationDetection\saved_model\resnet_baseline_fall_model.pth
#
# Epoch 02/10 | Train L 0.6635 A 0.628 P 0.597 R 0.494 F1 0.541 | Val L 0.0000 A 0.649 P 0.500 R 0.615 F1 0.552
#   Train CM:
# [[155  56]
#  [ 85  83]]
#   Val   CM:
# [[48 24]
#  [15 24]]
#
# Saved best model (val F1=0.552) → C:\Users\Asus\Desktop\School_SIT\Year_2_Tri_1\COMPUTER_VISION\FallHazardPoseEstimationDetection\saved_model\resnet_baseline_fall_model.pth
#
# Epoch 03/10 | Train L 0.6245 A 0.678 P 0.629 R 0.667 F1 0.647 | Val L 0.0000 A 0.685 P 0.538 R 0.718 F1 0.615
#   Train CM:
# [[145  66]
#  [ 56 112]]
#   Val   CM:
# [[48 24]
#  [11 28]]
#
# Saved best model (val F1=0.615) → C:\Users\Asus\Desktop\School_SIT\Year_2_Tri_1\COMPUTER_VISION\FallHazardPoseEstimationDetection\saved_model\resnet_baseline_fall_model.pth
#
# Epoch 04/10 | Train L 0.5866 A 0.741 P 0.727 R 0.667 F1 0.696 | Val L 0.0000 A 0.730 P 0.596 R 0.718 F1 0.651
#   Train CM:
# [[169  42]
#  [ 56 112]]
#   Val   CM:
# [[53 19]
#  [11 28]]
#
# Saved best model (val F1=0.651) → C:\Users\Asus\Desktop\School_SIT\Year_2_Tri_1\COMPUTER_VISION\FallHazardPoseEstimationDetection\saved_model\resnet_baseline_fall_model.pth
#
# Epoch 05/10 | Train L 0.5705 A 0.741 P 0.701 R 0.726 F1 0.713 | Val L 0.0000 A 0.730 P 0.592 R 0.744 F1 0.659
#   Train CM:
# [[159  52]
#  [ 46 122]]
#   Val   CM:
# [[52 20]
#  [10 29]]
#
# Saved best model (val F1=0.659) → C:\Users\Asus\Desktop\School_SIT\Year_2_Tri_1\COMPUTER_VISION\FallHazardPoseEstimationDetection\saved_model\resnet_baseline_fall_model.pth
#
# Epoch 06/10 | Train L 0.5533 A 0.773 P 0.750 R 0.732 F1 0.741 | Val L 0.0000 A 0.748 P 0.641 R 0.641 F1 0.641
#   Train CM:
# [[170  41]
#  [ 45 123]]
#   Val   CM:
# [[58 14]
#  [14 25]]
#
# Epoch 07/10 | Train L 0.5359 A 0.773 P 0.766 R 0.702 F1 0.733 | Val L 0.0000 A 0.766 P 0.651 R 0.718 F1 0.683
#   Train CM:
# [[175  36]
#  [ 50 118]]
#   Val   CM:
# [[57 15]
#  [11 28]]
#
# Saved best model (val F1=0.683) → C:\Users\Asus\Desktop\School_SIT\Year_2_Tri_1\COMPUTER_VISION\FallHazardPoseEstimationDetection\saved_model\resnet_baseline_fall_model.pth
#
# Epoch 08/10 | Train L 0.5163 A 0.784 P 0.722 R 0.833 F1 0.773 | Val L 0.0000 A 0.766 P 0.633 R 0.795 F1 0.705
#   Train CM:
# [[157  54]
#  [ 28 140]]
#   Val   CM:
# [[54 18]
#  [ 8 31]]
#
# Saved best model (val F1=0.705) → C:\Users\Asus\Desktop\School_SIT\Year_2_Tri_1\COMPUTER_VISION\FallHazardPoseEstimationDetection\saved_model\resnet_baseline_fall_model.pth
#
# Epoch 09/10 | Train L 0.5069 A 0.789 P 0.756 R 0.774 F1 0.765 | Val L 0.0000 A 0.775 P 0.652 R 0.769 F1 0.706
#   Train CM:
# [[169  42]
#  [ 38 130]]
#   Val   CM:
# [[56 16]
#  [ 9 30]]
#
# Saved best model (val F1=0.706) → C:\Users\Asus\Desktop\School_SIT\Year_2_Tri_1\COMPUTER_VISION\FallHazardPoseEstimationDetection\saved_model\resnet_baseline_fall_model.pth
#
# Epoch 10/10 | Train L 0.4815 A 0.828 P 0.816 R 0.792 F1 0.804 | Val L 0.0000 A 0.793 P 0.690 R 0.744 F1 0.716
#   Train CM:
# [[181  30]
#  [ 35 133]]
#   Val   CM:
# [[59 13]
#  [10 29]]
#
# Saved best model (val F1=0.716) → C:\Users\Asus\Desktop\School_SIT\Year_2_Tri_1\COMPUTER_VISION\FallHazardPoseEstimationDetection\saved_model\resnet_baseline_fall_model.pth
#
# Done.

# %% [markdown]
# resnet_fall_classification:
#
# Epoch 01/10 | Train L 0.4098 A 0.443 P 0.414 R 0.613 F1 0.494 | Val L 0.2882 A 0.414 P 0.352 R 0.795 F1 0.488
#   Train CM:
# [[ 65 146]
#  [ 65 103]]
#   Val   CM:
# [[15 57]
#  [ 8 31]]
#
# Saved best model (val F1=0.488) → C:\Users\Asus\Desktop\School_SIT\Year_2_Tri_1\COMPUTER_VISION\FallHazardPoseEstimationDetection\saved_model\resnet_fall_model.pth
#
# Epoch 02/10 | Train L 0.3307 A 0.504 P 0.450 R 0.542 F1 0.492 | Val L 0.2015 A 0.604 P 0.449 R 0.564 F1 0.500
#   Train CM:
# [[100 111]
#  [ 77  91]]
#   Val   CM:
# [[45 27]
#  [17 22]]
#
# Saved best model (val F1=0.500) → C:\Users\Asus\Desktop\School_SIT\Year_2_Tri_1\COMPUTER_VISION\FallHazardPoseEstimationDetection\saved_model\resnet_fall_model.pth
#
# Epoch 03/10 | Train L 0.2984 A 0.549 P 0.491 R 0.476 F1 0.483 | Val L 0.1883 A 0.649 P 0.500 R 0.564 F1 0.530
#   Train CM:
# [[128  83]
#  [ 88  80]]
#   Val   CM:
# [[50 22]
#  [17 22]]
#
# Saved best model (val F1=0.530) → C:\Users\Asus\Desktop\School_SIT\Year_2_Tri_1\COMPUTER_VISION\FallHazardPoseEstimationDetection\saved_model\resnet_fall_model.pth
#
# Epoch 04/10 | Train L 0.3163 A 0.567 P 0.511 R 0.536 F1 0.523 | Val L 0.1797 A 0.685 P 0.550 R 0.564 F1 0.557
#   Train CM:
# [[125  86]
#  [ 78  90]]
#   Val   CM:
# [[54 18]
#  [17 22]]
#
# Saved best model (val F1=0.557) → C:\Users\Asus\Desktop\School_SIT\Year_2_Tri_1\COMPUTER_VISION\FallHazardPoseEstimationDetection\saved_model\resnet_fall_model.pth
#
# Epoch 05/10 | Train L 0.2915 A 0.567 P 0.514 R 0.452 F1 0.481 | Val L 0.1753 A 0.694 P 0.564 R 0.564 F1 0.564
#   Train CM:
# [[139  72]
#  [ 92  76]]
#   Val   CM:
# [[55 17]
#  [17 22]]
#
# Saved best model (val F1=0.564) → C:\Users\Asus\Desktop\School_SIT\Year_2_Tri_1\COMPUTER_VISION\FallHazardPoseEstimationDetection\saved_model\resnet_fall_model.pth
#
# Epoch 06/10 | Train L 0.3161 A 0.583 P 0.529 R 0.536 F1 0.533 | Val L 0.1910 A 0.640 P 0.492 R 0.744 F1 0.592
#   Train CM:
# [[131  80]
#  [ 78  90]]
#   Val   CM:
# [[42 30]
#  [10 29]]
#
# Saved best model (val F1=0.592) → C:\Users\Asus\Desktop\School_SIT\Year_2_Tri_1\COMPUTER_VISION\FallHazardPoseEstimationDetection\saved_model\resnet_fall_model.pth
#
# Epoch 07/10 | Train L 0.2796 A 0.580 P 0.527 R 0.530 F1 0.528 | Val L 0.1676 A 0.703 P 0.575 R 0.590 F1 0.582
#   Train CM:
# [[131  80]
#  [ 79  89]]
#   Val   CM:
# [[55 17]
#  [16 23]]
#
# Epoch 08/10 | Train L 0.2787 A 0.591 P 0.538 R 0.554 F1 0.545 | Val L 0.1669 A 0.703 P 0.579 R 0.564 F1 0.571
#   Train CM:
# [[131  80]
#  [ 75  93]]
#   Val   CM:
# [[56 16]
#  [17 22]]
#
# Epoch 09/10 | Train L 0.2670 A 0.583 P 0.529 R 0.548 F1 0.538 | Val L 0.1643 A 0.721 P 0.595 R 0.641 F1 0.617
#   Train CM:
# [[129  82]
#  [ 76  92]]
#   Val   CM:
# [[55 17]
#  [14 25]]
#
# Saved best model (val F1=0.617) → C:\Users\Asus\Desktop\School_SIT\Year_2_Tri_1\COMPUTER_VISION\FallHazardPoseEstimationDetection\saved_model\resnet_fall_model.pth
#
# Epoch 10/10 | Train L 0.2642 A 0.578 P 0.523 R 0.536 F1 0.529 | Val L 0.1660 A 0.712 P 0.585 R 0.615 F1 0.600
#   Train CM:
# [[129  82]
#  [ 78  90]]
#   Val   CM:
# [[55 17]
#  [15 24]]
#
# Done.

# %% [markdown]
# I feel that they performed badly hence gonna do more optimizing using the following:
#
# python resnet_fall_classification.py --epochs 20 --unfreeze-backbone --lr 1e-5
# python efficientnet_fall_classification.py --epochs 20 --unfreeze-backbone --lr 1e-5
